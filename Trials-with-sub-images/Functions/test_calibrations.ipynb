# %%
import scipy.io as scio
import matplotlib.pyplot as plt

# %%
for i in range(1,8):
    calibration = scio.loadmat('./Calibrations/cal' + str(i) + '.mat')
    wavenumbers = calibration['Cal'][0][0][0]/10

    plt.plot(wavenumbers)

# %% [markdown]
# YES, ALL CALIBRATIONS ARE THE SAME! thank god :)
